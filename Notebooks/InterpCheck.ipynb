# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
# %matplotlib notebook

# %%
T5750i = pd.read_csv("T_5750.csv")
T5750 = pd.read_csv("T5750g4.50z+0.00c+0.00.dat", header=None, sep="\s+")
T5800 = pd.read_csv("t_5800.csv")
T5850 = pd.read_csv("t_5850.csv")
T5900 = pd.read_csv("t_5900.csv")
T5950 = pd.read_csv("t_5950.csv")
T6000 = pd.read_csv("t_6000.csv")
T5750.columns
# Out:
# Int64Index([0, 1, 2], dtype='int64')

# %%
z000 = pd.read_csv("T6000g4.50z+0.00c-1.00.dat", header=None, sep="\s+")
z010 = pd.read_csv("T6000g4.50z+0.10c-1.00.dat")
z020 = pd.read_csv("T6000g4.50z+0.20c-1.00.dat")
z025 = pd.read_csv("T6000g4.50z+0.25c-1.00.dat", header=None, sep="\s+")
z030 = pd.read_csv("T6000g4.50z+0.30c-1.00.dat")
z040 = pd.read_csv("T6000g4.50z+0.40c-1.00.dat")
z050 = pd.read_csv("T6000g4.50z+0.50c-1.00.dat", header=None, sep="\s+")

# %%
COLOR = cm.get_cmap('viridis')
RANGE = np.linspace(0,1,7)

# %%
fig = plt.figure()
alphaset = 0.75
plt.plot(z000[0], z000[2], color="black", alpha=alphaset)
plt.plot(z010.wl, z010.flux, color="red", alpha=alphaset)

plt.plot(z025[0], z025[2], color="purple", alpha=alphaset)

plt.plot(z030.wl, z030.flux, color=COLOR(RANGE[3]), alpha=alphaset)

print np.mean(z010.flux)
plt.show()
# Out:
# <img src="data:image/png;base64,...">
# 1993887.992

# %%
fig = plt.figure()
plt.plot(T5750[0], T5750[2],color=COLOR(RANGE[0]))
plt.plot(T5750i.wl, T5750i.flux, color=COLOR(RANGE[1]))
plt.plot(T5800.wl, T5800.flux, color=COLOR(RANGE[2]))
plt.show()
# Out:
# <img src="data:image/png;base64,...">
