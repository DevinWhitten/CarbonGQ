# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
Files = os.listdir(os.getcwd())
print Files
# Out:
# ['.ipynb_checkpoints', 'T4000g1.00z-3.00c+2.00.dat', 'T4250g1.00z-3.00c+2.00.dat', 'T4500g1.00z-3.00c+2.00.dat', 'T4750g1.00z-3.00c+2.00.dat', 'T5000g1.00z-3.00c+2.00.dat', 'T5250g1.00z-3.00c+2.00.dat', 'T5500g1.00z-3.00c+2.00.dat', 'T5750g1.00z-3.00c+2.00.dat', 'T6000g1.00z-3.00c+2.00.dat', 'TemperatureBehavior.ipynb']

# %%
Spectra = [pd.read_csv(Filename, header=None, sep="\s+") for Filename in Files[1:-1]]

# %%
fig = plt.figure()
[plt.plot(Spec[0], Spec[1], label=Name.split("g")[0]) for Spec,Name in zip(Spectra, Files[1:-1])]
plt.xlim([4200,4400])
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
